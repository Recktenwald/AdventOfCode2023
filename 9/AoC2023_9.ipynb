# %%
open System
open System.IO

# %%
let input = File.ReadAllLines("input_9.txt")
input
|> Array.map (fun line -> line.Split(" ") |> Array.map System.Int32.Parse)
|> Array.map (fun x -> x.Length)
|> Array.distinct
# Out:
# <div class="dni-plaintext"><pre>[ 21 ]</pre></div><style>
# .dni-code-hint {
#     font-style: italic;
#     overflow: hidden;
#     white-space: nowrap;
# }
# .dni-treeview {
#     white-space: nowrap;
# }
# .dni-treeview td {
#     vertical-align: top;
#     text-align: start;
# }
# details.dni-treeview {
#     padding-left: 1em;
# }
# table td {
#     text-align: start;
# }
# table tr {
#     vertical-align: top;
#     margin: 0em 0px;
# }
# table tr td pre
# {
#     vertical-align: top !important;
#     margin: 0em 0px !important;
# }
# table th {
#     text-align: start;
# }
# </style>

# %%
let createLagrangeFactor (n:int) (j:int) = 
    //special case of x_i = i for i = 0 to n-1 so n is the number of interpolation points
    let numerator = 
        [
            for xi in [0..n-1] do
                if xi <> j then 
                    n-xi
        ]
    
    let raw_denominator = 
        [
            for xi in [0..n-1] do 
                if xi<>j then 
                    j - xi 
        ]
    let sign = 
        raw_denominator 
        |> List.fold (fun state t -> state * (sign t)) 1
    let denominator = raw_denominator |> List.map abs
    {|
        Num = 
            numerator 
            // |> List.filter (fun x -> 
            //     denominator 
            //     |> List.contains x 
            //     |> not)
        Den = denominator
            // |> List.filter (fun x -> 
            //     denominator 
            //     |> List.contains x 
            //     |> not)
        Sign = sign
    |}

# %%
createLagrangeFactor 2 0
# Out:
# <details open="open" class="dni-treeview"><summary><span class="dni-code-hint"><code>{ Den = [1; 2]\n  Num = [1; 0]\n  Sign = 1 }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Den</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>[ 1, 2 ]</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>HeadOrDefault</td><td><div class="dni-plaintext"><pre>1</pre></div></td></tr><tr><td>TailOrNull</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>[ 2 ]</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>HeadOrDefault</td><td><div class="dni-plaintext"><pre>2</pre></div></td></tr><tr><td>TailOrNull</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>[  ]</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>HeadOrDefault</td><td><div class="dni-plaintext"><pre>0</pre></div></td></tr><tr><td>TailOrNull</td><td><div clas
# ...

# %%
let n = 2
let j = 0
[
    for xi in [0..n-1] do
        if xi <> j then 
            n-xi
]
# Out:
# <details open="open" class="dni-treeview"><summary><span class="dni-code-hint"><code>[ 1, 0 ]</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>HeadOrDefault</td><td><div class="dni-plaintext"><pre>1</pre></div></td></tr><tr><td>TailOrNull</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>[ 0 ]</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>HeadOrDefault</td><td><div class="dni-plaintext"><pre>0</pre></div></td></tr><tr><td>TailOrNull</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>[  ]</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>HeadOrDefault</td><td><div class="dni-plaintext"><pre>0</pre></div></td></tr><tr><td>TailOrNull</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr><tr><td>Head</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>System.InvalidOperationException: The input list was 
# ...

# %%
let eval (as:float list) = 
    let n =
# Out:
# <details open="open" class="dni-treeview"><summary><span class="dni-code-hint"><code>{ Den = [1; 2]\n  Num = [2; 1]\n  Sign = 1 }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Den</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>[ 1, 2 ]</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>HeadOrDefault</td><td><div class="dni-plaintext"><pre>1</pre></div></td></tr><tr><td>TailOrNull</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>[ 2 ]</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>HeadOrDefault</td><td><div class="dni-plaintext"><pre>2</pre></div></td></tr><tr><td>TailOrNull</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>[  ]</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>HeadOrDefault</td><td><div class="dni-plaintext"><pre>0</pre></div></td></tr><tr><td>TailOrNull</td><td><div clas
# ...
